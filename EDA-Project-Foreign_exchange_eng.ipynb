# %% [markdown]
# # EDA-Project: Foreign exchange
#
# Making EDA by exchange rates by file: ```"foreign_exchange_rates.csv"```

# %% [markdown]
# # 1) Importing the required packages

# %%
import numpy as np
import pandas as pd
import csv
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # 2) Let's read the file and get general information

# %%
exchange=pd.read_csv('foreign_exchange_rates.csv')
exchange.head()
# Out:
#    Unnamed: 0  Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$  \
# 0           0  2000-01-03                            1.5172
# 1           1  2000-01-04                            1.5239
# 2           2  2000-01-05                            1.5267
# 3           3  2000-01-06                            1.5291
# 4           4  2000-01-07                            1.5272
#
#   EURO AREA - EURO/US$ NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0               0.9847                              1.9033
# 1                 0.97                              1.9238
# 2               0.9676                              1.9339
# 3               0.9686                              1.9436
# 4               0.9714                               1.938
#
#   UNITED KINGDOM - UNITED KINGDOM POUND/US$ BRAZIL - REAL/US$  \
# 0                                    0.6146             1.805
# 1                                    0.6109            1.8405
# 2                                    0.6092             1.856
# 3                                     0.607              1.84
# 4                                    0.6104             1.831
#
#   CANADA - CANADIAN DOLLAR/US$ CHINA - YUAN/US$  \
# 0                       1.4465           8.2798
# 1                       1.4518           8.2799
# 2                       1.4518           8.2798
# 3                       1.4571           8.2797
# 4                       1.4505           8.2794
#
#   HONG KONG - HONG KONG DOLLAR/US$  ... SINGAPORE - SINGAPORE DOLLAR/US$  \
# 0                           7.7765  ...                           1.6563
# 1                           7.7775  ...                           1.6535
# 2                            7.778  ...                            1.656
# 3                           7.7785  ...                           1.6655
# 4                           7.7783  ...                           1.6625
#
#   DENMARK - DANISH KRONE/US$ JAPAN - YEN/US$ MALAYSIA - RINGGIT/US$  \
# 0                      7.329           101.7                    3.8
# 1                      7.218          103.09                    3.8
# 2                      7.208          103.77                    3.8
# 3                     7.2125          105.19                    3.8
# 4                     7.2285          105.17                    3.8
#
#   NORWAY - NORWEGIAN KRONE/US$ SWEDEN - KRONA/US$  \
# 0                        7.964              8.443
# 1                        7.934               8.36
# 2                        7.935              8.353
# 3                         7.94             8.3675
# 4                        7.966              8.415
#
#   SRI LANKA - SRI LANKAN RUPEE/US$ SWITZERLAND - FRANC/US$  \
# 0                             72.3                  1.5808
# 1                            72.65                  1.5565
# 2                            72.95                  1.5526
# 3                            72.95                   1.554
# 4                            73.15                  1.5623
#
#   TAIWAN - NEW TAIWAN DOLLAR/US$ THAILAND - BAHT/US$
# 0                          31.38               36.97
# 1                           30.6               37.13
# 2                           30.8                37.1
# 3                          31.75               37.62
# 4                          30.85                37.3
#
# [5 rows x 24 columns]

# %% [markdown]
# Removing the first column as it is repeating the index

# %%
exchange.drop("Unnamed: 0", axis=1, inplace=True)
exchange.head()
# Out:
#    Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$ EURO AREA - EURO/US$  \
# 0  2000-01-03                            1.5172               0.9847
# 1  2000-01-04                            1.5239                 0.97
# 2  2000-01-05                            1.5267               0.9676
# 3  2000-01-06                            1.5291               0.9686
# 4  2000-01-07                            1.5272               0.9714
#
#   NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0                              1.9033
# 1                              1.9238
# 2                              1.9339
# 3                              1.9436
# 4                               1.938
#
#   UNITED KINGDOM - UNITED KINGDOM POUND/US$ BRAZIL - REAL/US$  \
# 0                                    0.6146             1.805
# 1                                    0.6109            1.8405
# 2                                    0.6092             1.856
# 3                                     0.607              1.84
# 4                                    0.6104             1.831
#
#   CANADA - CANADIAN DOLLAR/US$ CHINA - YUAN/US$  \
# 0                       1.4465           8.2798
# 1                       1.4518           8.2799
# 2                       1.4518           8.2798
# 3                       1.4571           8.2797
# 4                       1.4505           8.2794
#
#   HONG KONG - HONG KONG DOLLAR/US$ INDIA - INDIAN RUPEE/US$  ...  \
# 0                           7.7765                    43.55  ...
# 1                           7.7775                    43.55  ...
# 2                            7.778                    43.55  ...
# 3                           7.7785                    43.55  ...
# 4                           7.7783                    43.55  ...
#
#   SINGAPORE - SINGAPORE DOLLAR/US$ DENMARK - DANISH KRONE/US$ JAPAN - YEN/US$  \
# 0                           1.6563                      7.329           101.7
# 1                           1.6535                      7.218          103.09
# 2                            1.656                      7.208          103.77
# 3                           1.6655                     7.2125          105.19
# 4                           1.6625                     7.2285          105.17
#
#   MALAYSIA - RINGGIT/US$ NORWAY - NORWEGIAN KRONE/US$ SWEDEN - KRONA/US$  \
# 0                    3.8                        7.964              8.443
# 1                    3.8                        7.934               8.36
# 2                    3.8                        7.935              8.353
# 3                    3.8                         7.94             8.3675
# 4                    3.8                        7.966              8.415
#
#   SRI LANKA - SRI LANKAN RUPEE/US$ SWITZERLAND - FRANC/US$  \
# 0                             72.3                  1.5808
# 1                            72.65                  1.5565
# 2                            72.95                  1.5526
# 3                            72.95                   1.554
# 4                            73.15                  1.5623
#
#   TAIWAN - NEW TAIWAN DOLLAR/US$ THAILAND - BAHT/US$
# 0                          31.38               36.97
# 1                           30.6               37.13
# 2                           30.8                37.1
# 3                          31.75               37.62
# 4                          30.85                37.3
#
# [5 rows x 23 columns]

# %%
exchange.shape
# Out:
# (5217, 23)

# %%
exchange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5217 entries, 0 to 5216
# Data columns (total 23 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Time Serie                                 5217 non-null   object
#  1   AUSTRALIA - AUSTRALIAN DOLLAR/US$          5217 non-null   object
#  2   EURO AREA - EURO/US$                       5217 non-null   object
#  3   NEW ZEALAND - NEW ZELAND DOLLAR/US$        5217 non-null   object
#  4   UNITED KINGDOM - UNITED KINGDOM POUND/US$  5217 non-null   object
#  5   BRAZIL - REAL/US$                          5217 non-null   object
#  6   CANADA - CANADIAN DOLLAR/US$               5217 non-null   object
#  7   CHINA - YUAN/US$                           5217 non-null   object
#  8   HONG KONG - HONG KONG DOLLAR/US$           5217 non-null   object
#  9   INDIA - INDIAN RUPEE/US$                   5217 non-null   object
#  10  KOREA - WON/US$                            5217 non-null   object
#  11  MEXICO - MEXICAN PESO/US$                  5217 non-null   object
#  12  SOUTH AFRICA - RAND/US$                    5217 non-null   object
#  13  SINGAPORE - SINGAPORE DOLLAR/US$           5217 non-null   object
#  14  DENMARK - DANISH KRONE/US$                 5217 non-null   object
#  15  JAPAN - YEN/US$                            5217 non-null   object
#  16  MALAYSIA - RINGGIT/US$                     5217 non-null   object
#  17  NORWAY - NORWEGIAN KRONE/US$               5217 non-null   object
#  18  SWEDEN - KRONA/US$                         5217 non-null   object
#  19  SRI LANKA - SRI LANKAN RUPEE/US$           5217 non-null   object
#  20  SWITZERLAND - FRANC/US$                    5217 non-null   object
#  21  TAIWAN - NEW TAIWAN DOLLAR/US$             5217 non-null   object
#  22  THAILAND - BAHT/US$                        5217 non-null   object
# dtypes: object(23)
# memory usage: 937.6+ KB

# %%
exchange.describe()
# Out:
#         Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$ EURO AREA - EURO/US$  \
# count         5217                              5217                 5217
# unique        5217                              2959                 2704
# top     2002-03-25                                ND                   ND
# freq             1                               198                  198
#
#        NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# count                                 5217
# unique                                2681
# top                                     ND
# freq                                   198
#
#        UNITED KINGDOM - UNITED KINGDOM POUND/US$ BRAZIL - REAL/US$  \
# count                                       5217              5217
# unique                                      2303              3880
# top                                           ND                ND
# freq                                         198               198
#
#        CANADA - CANADIAN DOLLAR/US$ CHINA - YUAN/US$  \
# count                          5217             5217
# unique                         3147             2711
# top                              ND           8.2765
# freq                            198              208
#
#        HONG KONG - HONG KONG DOLLAR/US$ INDIA - INDIAN RUPEE/US$  ...  \
# count                              5217                     5217  ...
# unique                              893                     1998  ...
# top                                  ND                       ND  ...
# freq                                198                      199  ...
#
#        SINGAPORE - SINGAPORE DOLLAR/US$ DENMARK - DANISH KRONE/US$  \
# count                              5217                       5217
# unique                             2927                       4462
# top                                  ND                         ND
# freq                                198                        198
#
#        JAPAN - YEN/US$ MALAYSIA - RINGGIT/US$ NORWAY - NORWEGIAN KRONE/US$  \
# count             5217                   5217                         5217
# unique            2848                   1788                         4511
# top                 ND                    3.8                           ND
# freq               198                   1376                          198
#
#        SWEDEN - KRONA/US$ SRI LANKA - SRI LANKAN RUPEE/US$  \
# count                5217                             5217
# unique               4574                             1781
# top                    ND                               ND
# freq                  198                              198
#
#        SWITZERLAND - FRANC/US$ TAIWAN - NEW TAIWAN DOLLAR/US$  \
# count                     5217                           5217
# unique                    3190                            714
# top                         ND                             ND
# freq                       198                            201
#
#        THAILAND - BAHT/US$
# count                 5217
# unique                1380
# top                     ND
# freq                   198
#
# [4 rows x 23 columns]

# %% [markdown]
# # 3) Let's start with the Euro column

# %% [markdown]
# We work on the column "EURO AREA - EURO / US $", change its name to "Euro". Divide the "Time Serie" column into days, months, years and days of the week to find out on which day of the week the data is most absent

# %%
euro_dollar=exchange[["Time Serie","EURO AREA - EURO/US$"]]
euro_dollar.columns = ["Time Serie","Euro"]
euro_dollar.head()
# Out:
#    Time Serie    Euro
# 0  2000-01-03  0.9847
# 1  2000-01-04    0.97
# 2  2000-01-05  0.9676
# 3  2000-01-06  0.9686
# 4  2000-01-07  0.9714

# %%
euro_dollar["Day"] = euro_dollar["Time Serie"].apply(lambda x: datetime.strptime(x,"%Y-%m-%d").day)
euro_dollar["Month"] = euro_dollar["Time Serie"].apply(lambda x: datetime.strptime(x,"%Y-%m-%d").month)
euro_dollar["Year"] = euro_dollar["Time Serie"].apply(lambda x: datetime.strptime(x, "%Y-%m-%d").year)
euro_dollar["Weekday"] = euro_dollar["Time Serie"].apply(lambda x: datetime.strftime(datetime.strptime(x, "%Y-%m-%d"), "%A"))
euro_dollar.drop("Time Serie", axis=1, inplace=True)
euro_dollar.head()
# Out:
# c:\users\user\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\user\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\user\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\user\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# c:\users\user\anaconda3\envs\py36\lib\site-packages\pandas\core\frame.py:4170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      Euro  Day  Month  Year    Weekday
# 0  0.9847    3      1  2000     Monday
# 1    0.97    4      1  2000    Tuesday
# 2  0.9676    5      1  2000  Wednesday
# 3  0.9686    6      1  2000   Thursday
# 4  0.9714    7      1  2000     Friday

# %% [markdown]
# Let's calculate on which day of the week the data are most absent

# %%
counter = []
for i in euro_dollar[euro_dollar["Euro"]=="ND"].index:
    counter.append(euro_dollar["Weekday"][i])
count=pd.Series(counter)
count.value_counts()
# Out:
# Monday       124
# Thursday      30
# Friday        16
# Tuesday       15
# Wednesday     13
# dtype: int64

# %% [markdown]
# Dropping all rows with no data

# %%
euro_dollar=(euro_dollar[euro_dollar['Euro']!="ND"])
euro_dollar.dropna()
euro_dollar['Euro']=euro_dollar['Euro'].astype(float)
euro_dollar
# Out:
#         Euro  Day  Month  Year    Weekday
# 0     0.9847    3      1  2000     Monday
# 1     0.9700    4      1  2000    Tuesday
# 2     0.9676    5      1  2000  Wednesday
# 3     0.9686    6      1  2000   Thursday
# 4     0.9714    7      1  2000     Friday
# ...      ...  ...    ...   ...        ...
# 5211  0.9022   24     12  2019    Tuesday
# 5213  0.9007   26     12  2019   Thursday
# 5214  0.8949   27     12  2019     Friday
# 5215  0.8915   30     12  2019     Monday
# 5216  0.8907   31     12  2019    Tuesday
#
# [5019 rows x 5 columns]

# %% [markdown]
# We check in which day of the week was the maximum and minimum value of Euro and the maximum and minimum values for each year

# %%
max_euro_week_day = (euro_dollar[euro_dollar["Euro"]==euro_dollar["Euro"].max()]["Weekday"])
min_euro_week_day = (euro_dollar[euro_dollar["Euro"]==euro_dollar["Euro"].min()]["Weekday"])
print(f"Maximum value of Euro was in {max_euro_week_day[max_euro_week_day.index[0]]}")
print(f"Minimum value of Euro was in {min_euro_week_day[min_euro_week_day.index[0]]}")
# Out:
# Maximum value of Euro was in Wednesday
# Minimum value of Euro was in Tuesday

# %%
for i in euro_dollar["Year"].unique():
    print(f'{i}: min: {euro_dollar[euro_dollar["Year"]==i].min()["Euro"]}\tmax: {euro_dollar[euro_dollar["Year"]==i].max()["Euro"]}')
# Out:
# 2000: min: 0.9676	max: 1.2092
# 2001: min: 1.0488	max: 1.1947
# 2002: min: 0.9537	max: 1.1636
# 2003: min: 0.7938	max: 0.9652
# 2004: min: 0.7339	max: 0.8474
# 2005: min: 0.7421	max: 0.8571
# 2006: min: 0.7504	max: 0.8432
# 2007: min: 0.6729	max: 0.775
# 2008: min: 0.6246	max: 0.8035
# 2009: min: 0.6623	max: 0.797
# 2010: min: 0.6879	max: 0.8362
# 2011: min: 0.6723	max: 0.7736
# 2012: min: 0.7428	max: 0.829
# 2013: min: 0.7238	max: 0.7828
# 2014: min: 0.718	max: 0.8264
# 2015: min: 0.8323	max: 0.9502
# 2016: min: 0.8684	max: 0.9639
# 2017: min: 0.8305	max: 0.9601
# 2018: min: 0.8008	max: 0.8864
# 2019: min: 0.8678	max: 0.917

# %%
max_euro_year = (euro_dollar[euro_dollar["Euro"]==euro_dollar["Euro"].max()]["Year"])
min_euro_year = (euro_dollar[euro_dollar["Euro"]==euro_dollar["Euro"].min()]["Year"])
print(f"Maximum value of Euro was in {max_euro_year[max_euro_year.index[0]]}")
print(f"Minimum value of Euro was in {min_euro_year[min_euro_year.index[0]]}")
# Out:
# Maximum value of Euro was in 2000
# Minimum value of Euro was in 2008

# %% [markdown]
# # 4) Now we work in all columns

# %% [markdown]
# Dropping all rows without data

# %%
for i in exchange.columns.unique():
    new_exchange=(exchange[exchange[i]!="ND"])
new_exchange.dropna()
# Out:
#       Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$ EURO AREA - EURO/US$  \
# 0     2000-01-03                            1.5172               0.9847
# 1     2000-01-04                            1.5239                 0.97
# 2     2000-01-05                            1.5267               0.9676
# 3     2000-01-06                            1.5291               0.9686
# 4     2000-01-07                            1.5272               0.9714
# ...          ...                               ...                  ...
# 5211  2019-12-24                            1.4445               0.9022
# 5213  2019-12-26                            1.4411               0.9007
# 5214  2019-12-27                            1.4331               0.8949
# 5215  2019-12-30                            1.4278               0.8915
# 5216  2019-12-31                            1.4225               0.8907
#
#      NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0                                 1.9033
# 1                                 1.9238
# 2                                 1.9339
# 3                                 1.9436
# 4                                  1.938
# ...                                  ...
# 5211                              1.5058
# 5213                              1.5002
# 5214                              1.4919
# 5215                              1.4846
# 5216                              1.4826
#
#      UNITED KINGDOM - UNITED KINGDOM POUND/US$ BRAZIL - REAL/US$  \
# 0                                       0.6146             1.805
# 1                                       0.6109            1.8405
# 2                                       0.6092             1.856
# 3                                        0.607              1.84
# 4                                       0.6104             1.831
# ...                                        ...               ...
# 5211                                    0.7719            4.0833
# 5213                                    0.7688            4.0602
# 5214                                    0.7639            4.0507
# 5215                                     0.761            4.0152
# 5216                                    0.7536             4.019
#
#      CANADA - CANADIAN DOLLAR/US$ CHINA - YUAN/US$  \
# 0                          1.4465           8.2798
# 1                          1.4518           8.2799
# 2                          1.4518           8.2798
# 3                          1.4571           8.2797
# 4                          1.4505           8.2794
# ...                           ...              ...
# 5211                        1.316           7.0064
# 5213                       1.3124           6.9949
# 5214                       1.3073           6.9954
# 5215                       1.3058           6.9864
# 5216                       1.2962           6.9618
#
#      HONG KONG - HONG KONG DOLLAR/US$ INDIA - INDIAN RUPEE/US$  ...  \
# 0                              7.7765                    43.55  ...
# 1                              7.7775                    43.55  ...
# 2                               7.778                    43.55  ...
# 3                              7.7785                    43.55  ...
# 4                              7.7783                    43.55  ...
# ...                               ...                      ...  ...
# 5211                           7.7872                    71.23  ...
# 5213                            7.788                    71.28  ...
# 5214                           7.7874                    71.45  ...
# 5215                           7.7857                     71.3  ...
# 5216                           7.7894                    71.36  ...
#
#      SINGAPORE - SINGAPORE DOLLAR/US$ DENMARK - DANISH KRONE/US$  \
# 0                              1.6563                      7.329
# 1                              1.6535                      7.218
# 2                               1.656                      7.208
# 3                              1.6655                     7.2125
# 4                              1.6625                     7.2285
# ...                               ...                        ...
# 5211                            1.355                     6.7399
# 5213                            1.354                     6.7295
# 5214                            1.352                     6.6829
# 5215                           1.3483                     6.6589
# 5216                           1.3446                     6.6554
#
#      JAPAN - YEN/US$ MALAYSIA - RINGGIT/US$ NORWAY - NORWEGIAN KRONE/US$  \
# 0              101.7                    3.8                        7.964
# 1             103.09                    3.8                        7.934
# 2             103.77                    3.8                        7.935
# 3             105.19                    3.8                         7.94
# 4             105.17                    3.8                        7.966
# ...              ...                    ...                          ...
# 5211          109.38                  4.135                       8.9142
# 5213          109.67                 4.1337                       8.8799
# 5214          109.47                  4.126                       8.8291
# 5215          108.85                 4.1053                       8.7839
# 5216          108.67                 4.0918                       8.7823
#
#      SWEDEN - KRONA/US$ SRI LANKA - SRI LANKAN RUPEE/US$  \
# 0                 8.443                             72.3
# 1                  8.36                            72.65
# 2                 8.353                            72.95
# 3                8.3675                            72.95
# 4                 8.415                            73.15
# ...                 ...                              ...
# 5211             9.4133                            181.3
# 5213             9.4108                            181.3
# 5214             9.3405                           181.35
# 5215             9.3145                            181.6
# 5216             9.3425                            181.3
#
#      SWITZERLAND - FRANC/US$ TAIWAN - NEW TAIWAN DOLLAR/US$  \
# 0                     1.5808                          31.38
# 1                     1.5565                           30.6
# 2                     1.5526                           30.8
# 3                      1.554                          31.75
# 4                     1.5623                          30.85
# ...                      ...                            ...
# 5211                  0.9807                          30.14
# 5213                  0.9808                          30.11
# 5214                  0.9741                          30.09
# 5215                  0.9677                          30.04
# 5216                  0.9677                          29.91
#
#      THAILAND - BAHT/US$
# 0                  36.97
# 1                  37.13
# 2                   37.1
# 3                  37.62
# 4                   37.3
# ...                  ...
# 5211               30.15
# 5213               30.15
# 5214               30.14
# 5215               29.94
# 5216               29.75
#
# [5019 rows x 23 columns]

# %% [markdown]
# Change the column names to make them understandable

# %%
col_names = []
col_names.append("Time Serie")
for i in new_exchange.columns[1:]:
    col_names.append(i.split("/")[0].split("-")[1].strip(" "))

# %%
print(col_names)
# Out:
# ['Time Serie', 'AUSTRALIAN DOLLAR', 'EURO', 'NEW ZELAND DOLLAR', 'UNITED KINGDOM POUND', 'REAL', 'CANADIAN DOLLAR', 'YUAN', 'HONG KONG DOLLAR', 'INDIAN RUPEE', 'WON', 'MEXICAN PESO', 'RAND', 'SINGAPORE DOLLAR', 'DANISH KRONE', 'YEN', 'RINGGIT', 'NORWEGIAN KRONE', 'KRONA', 'SRI LANKAN RUPEE', 'FRANC', 'NEW TAIWAN DOLLAR', 'BAHT']

# %%
new_exchange.columns = col_names
new_exchange
# Out:
#       Time Serie AUSTRALIAN DOLLAR    EURO NEW ZELAND DOLLAR  \
# 0     2000-01-03            1.5172  0.9847            1.9033
# 1     2000-01-04            1.5239    0.97            1.9238
# 2     2000-01-05            1.5267  0.9676            1.9339
# 3     2000-01-06            1.5291  0.9686            1.9436
# 4     2000-01-07            1.5272  0.9714             1.938
# ...          ...               ...     ...               ...
# 5211  2019-12-24            1.4445  0.9022            1.5058
# 5213  2019-12-26            1.4411  0.9007            1.5002
# 5214  2019-12-27            1.4331  0.8949            1.4919
# 5215  2019-12-30            1.4278  0.8915            1.4846
# 5216  2019-12-31            1.4225  0.8907            1.4826
#
#      UNITED KINGDOM POUND    REAL CANADIAN DOLLAR    YUAN HONG KONG DOLLAR  \
# 0                  0.6146   1.805          1.4465  8.2798           7.7765
# 1                  0.6109  1.8405          1.4518  8.2799           7.7775
# 2                  0.6092   1.856          1.4518  8.2798            7.778
# 3                   0.607    1.84          1.4571  8.2797           7.7785
# 4                  0.6104   1.831          1.4505  8.2794           7.7783
# ...                   ...     ...             ...     ...              ...
# 5211               0.7719  4.0833           1.316  7.0064           7.7872
# 5213               0.7688  4.0602          1.3124  6.9949            7.788
# 5214               0.7639  4.0507          1.3073  6.9954           7.7874
# 5215                0.761  4.0152          1.3058  6.9864           7.7857
# 5216               0.7536   4.019          1.2962  6.9618           7.7894
#
#      INDIAN RUPEE  ... SINGAPORE DOLLAR DANISH KRONE     YEN RINGGIT  \
# 0           43.55  ...           1.6563        7.329   101.7     3.8
# 1           43.55  ...           1.6535        7.218  103.09     3.8
# 2           43.55  ...            1.656        7.208  103.77     3.8
# 3           43.55  ...           1.6655       7.2125  105.19     3.8
# 4           43.55  ...           1.6625       7.2285  105.17     3.8
# ...           ...  ...              ...          ...     ...     ...
# 5211        71.23  ...            1.355       6.7399  109.38   4.135
# 5213        71.28  ...            1.354       6.7295  109.67  4.1337
# 5214        71.45  ...            1.352       6.6829  109.47   4.126
# 5215         71.3  ...           1.3483       6.6589  108.85  4.1053
# 5216        71.36  ...           1.3446       6.6554  108.67  4.0918
#
#      NORWEGIAN KRONE   KRONA SRI LANKAN RUPEE   FRANC NEW TAIWAN DOLLAR   BAHT
# 0              7.964   8.443             72.3  1.5808             31.38  36.97
# 1              7.934    8.36            72.65  1.5565              30.6  37.13
# 2              7.935   8.353            72.95  1.5526              30.8   37.1
# 3               7.94  8.3675            72.95   1.554             31.75  37.62
# 4              7.966   8.415            73.15  1.5623             30.85   37.3
# ...              ...     ...              ...     ...               ...    ...
# 5211          8.9142  9.4133            181.3  0.9807             30.14  30.15
# 5213          8.8799  9.4108            181.3  0.9808             30.11  30.15
# 5214          8.8291  9.3405           181.35  0.9741             30.09  30.14
# 5215          8.7839  9.3145            181.6  0.9677             30.04  29.94
# 5216          8.7823  9.3425            181.3  0.9677             29.91  29.75
#
# [5019 rows x 23 columns]

# %% [markdown]
# Plotting a chart over the years for the Australian, New Zealand and Singapore dollars

# %%
new_data=new_exchange[["Time Serie", "AUSTRALIAN DOLLAR", "NEW ZELAND DOLLAR", "SINGAPORE DOLLAR"]]
new_data
# Out:
#       Time Serie AUSTRALIAN DOLLAR NEW ZELAND DOLLAR SINGAPORE DOLLAR
# 0     2000-01-03            1.5172            1.9033           1.6563
# 1     2000-01-04            1.5239            1.9238           1.6535
# 2     2000-01-05            1.5267            1.9339            1.656
# 3     2000-01-06            1.5291            1.9436           1.6655
# 4     2000-01-07            1.5272             1.938           1.6625
# ...          ...               ...               ...              ...
# 5211  2019-12-24            1.4445            1.5058            1.355
# 5213  2019-12-26            1.4411            1.5002            1.354
# 5214  2019-12-27            1.4331            1.4919            1.352
# 5215  2019-12-30            1.4278            1.4846           1.3483
# 5216  2019-12-31            1.4225            1.4826           1.3446
#
# [5019 rows x 4 columns]

# %%
new_data["Year"] = new_data["Time Serie"].apply(lambda x: datetime.strptime(x, "%Y-%m-%d").year)
new_data.drop("Time Serie", axis=1)
# Out:
# c:\users\user\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      AUSTRALIAN DOLLAR NEW ZELAND DOLLAR SINGAPORE DOLLAR  Year
# 0               1.5172            1.9033           1.6563  2000
# 1               1.5239            1.9238           1.6535  2000
# 2               1.5267            1.9339            1.656  2000
# 3               1.5291            1.9436           1.6655  2000
# 4               1.5272             1.938           1.6625  2000
# ...                ...               ...              ...   ...
# 5211            1.4445            1.5058            1.355  2019
# 5213            1.4411            1.5002            1.354  2019
# 5214            1.4331            1.4919            1.352  2019
# 5215            1.4278            1.4846           1.3483  2019
# 5216            1.4225            1.4826           1.3446  2019
#
# [5019 rows x 4 columns]

# %%
new_data=new_data.astype({"AUSTRALIAN DOLLAR":"float", "NEW ZELAND DOLLAR":"float", "SINGAPORE DOLLAR":"float"})

# %%
Australian = []
New_Zeland = []
Singapore = []
for i in new_data["Year"].unique():
    Australian.append(new_data[new_data["Year"]==i].mean()["AUSTRALIAN DOLLAR"])
    New_Zeland.append(new_data[new_data["Year"]==i].mean()["NEW ZELAND DOLLAR"])
    Singapore.append(new_data[new_data["Year"]==i].mean()["SINGAPORE DOLLAR"])
    
Australian = pd.DataFrame(Australian, columns=["Australian"])
New_Zeland = pd.DataFrame(New_Zeland, columns=["New_Zeland"])
Singapore = pd.DataFrame(Singapore, columns=["Singapore"])
Year = pd.DataFrame(new_data["Year"].unique(), columns=["Year"])
pd_data = pd.concat([Australian, New_Zeland, Singapore, Year], axis=1)
pd_data
# Out:
#     Australian  New_Zeland  Singapore  Year
# 0     1.727126    2.204233   1.724978  2000
# 1     1.936453    2.381929   1.792972  2001
# 2     1.841163    2.161254   1.790782  2002
# 3     1.540872    1.722408   1.742909  2003
# 4     1.360242    1.508478   1.690208  2004
# 5     1.311738    1.419382   1.663917  2005
# 6     1.327884    1.543045   1.588243  2006
# 7     1.194504    1.360346   1.506506  2007
# 8     1.194603    1.422221   1.413977  2008
# 9     1.280020    1.597137   1.454262  2009
# 10    1.089864    1.387603   1.362936  2010
# 11    0.968790    1.264909   1.256512  2011
# 12    0.965857    1.234682   1.249170  2012
# 13    1.036169    1.219778   1.251063  2013
# 14    1.108624    1.204860   1.266538  2014
# 15    1.332021    1.434496   1.374609  2015
# 16    1.344380    1.435276   1.380006  2016
# 17    1.304396    1.407191   1.380219  2017
# 18    1.338468    1.445482   1.348624  2018
# 19    1.438971    1.518363   1.364098  2019

# %%
sns.set(style="ticks");
sns.set_context("talk");

for i in pd_data.columns[:3]:
    g = sns.catplot(x="Year", y=i, data=pd_data, kind='bar');
    g.set(xticks=[1,6,13,19], xticklabels=[2000,2006,2013,2019])
    g.ax.set_title(f"Information for {i} dollar")

# %% [markdown]
# Let's get the high, low and average values for each currency

# %%
new_exchange["Year"] = new_exchange["Time Serie"].apply(lambda x: datetime.strptime(x, "%Y-%m-%d").year)
new_exchange = new_exchange.drop("Time Serie", axis=1)
new_exchange = new_exchange.drop("INDIAN RUPEE", axis=1)
new_exchange = new_exchange.drop("NEW TAIWAN DOLLAR", axis=1)
new_exchange
# Out:
# c:\users\user\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      AUSTRALIAN DOLLAR    EURO NEW ZELAND DOLLAR UNITED KINGDOM POUND    REAL  \
# 0               1.5172  0.9847            1.9033               0.6146   1.805
# 1               1.5239    0.97            1.9238               0.6109  1.8405
# 2               1.5267  0.9676            1.9339               0.6092   1.856
# 3               1.5291  0.9686            1.9436                0.607    1.84
# 4               1.5272  0.9714             1.938               0.6104   1.831
# ...                ...     ...               ...                  ...     ...
# 5211            1.4445  0.9022            1.5058               0.7719  4.0833
# 5213            1.4411  0.9007            1.5002               0.7688  4.0602
# 5214            1.4331  0.8949            1.4919               0.7639  4.0507
# 5215            1.4278  0.8915            1.4846                0.761  4.0152
# 5216            1.4225  0.8907            1.4826               0.7536   4.019
#
#      CANADIAN DOLLAR    YUAN HONG KONG DOLLAR      WON MEXICAN PESO  ...  \
# 0             1.4465  8.2798           7.7765     1128       9.4015  ...
# 1             1.4518  8.2799           7.7775   1122.5        9.457  ...
# 2             1.4518  8.2798            7.778     1135        9.535  ...
# 3             1.4571  8.2797           7.7785   1146.5        9.567  ...
# 4             1.4505  8.2794           7.7783     1138         9.52  ...
# ...              ...     ...              ...      ...          ...  ...
# 5211           1.316  7.0064           7.7872  1163.21       18.955  ...
# 5213          1.3124  6.9949            7.788  1161.18       18.944  ...
# 5214          1.3073  6.9954           7.7874  1160.87       18.819  ...
# 5215          1.3058  6.9864           7.7857  1155.75       18.863  ...
# 5216          1.2962  6.9618           7.7894  1155.46        18.86  ...
#
#      SINGAPORE DOLLAR DANISH KRONE     YEN RINGGIT NORWEGIAN KRONE   KRONA  \
# 0              1.6563        7.329   101.7     3.8           7.964   8.443
# 1              1.6535        7.218  103.09     3.8           7.934    8.36
# 2               1.656        7.208  103.77     3.8           7.935   8.353
# 3              1.6655       7.2125  105.19     3.8            7.94  8.3675
# 4              1.6625       7.2285  105.17     3.8           7.966   8.415
# ...               ...          ...     ...     ...             ...     ...
# 5211            1.355       6.7399  109.38   4.135          8.9142  9.4133
# 5213            1.354       6.7295  109.67  4.1337          8.8799  9.4108
# 5214            1.352       6.6829  109.47   4.126          8.8291  9.3405
# 5215           1.3483       6.6589  108.85  4.1053          8.7839  9.3145
# 5216           1.3446       6.6554  108.67  4.0918          8.7823  9.3425
#
#      SRI LANKAN RUPEE   FRANC   BAHT  Year
# 0                72.3  1.5808  36.97  2000
# 1               72.65  1.5565  37.13  2000
# 2               72.95  1.5526   37.1  2000
# 3               72.95   1.554  37.62  2000
# 4               73.15  1.5623   37.3  2000
# ...               ...     ...    ...   ...
# 5211            181.3  0.9807  30.15  2019
# 5213            181.3  0.9808  30.15  2019
# 5214           181.35  0.9741  30.14  2019
# 5215            181.6  0.9677  29.94  2019
# 5216            181.3  0.9677  29.75  2019
#
# [5019 rows x 21 columns]

# %%
res = {}
counter = {}
for i in new_exchange.columns[:-1]:
    new_exchange[i]=new_exchange[i].astype("float")
    new_exchange["Year"]=new_exchange["Year"].astype("int")
    for j in new_exchange["Year"].unique():
        counter[i]=new_exchange[new_exchange["Year"]==j].mean()[i]

# %%
pd_data = pd.DataFrame.from_dict(counter, orient="index", columns=["Mean value"])
pd_data
# Out:
#                        Mean value
# AUSTRALIAN DOLLAR        1.438971
# EURO                     0.893438
# NEW ZELAND DOLLAR        1.518363
# UNITED KINGDOM POUND     0.783731
# REAL                     3.943966
# CANADIAN DOLLAR          1.326946
# YUAN                     6.908139
# HONG KONG DOLLAR         7.835074
# WON                   1165.801566
# MEXICAN PESO            19.246934
# RAND                    14.447534
# SINGAPORE DOLLAR         1.364098
# DANISH KRONE             6.670322
# YEN                    109.018835
# RINGGIT                  4.141557
# NORWEGIAN KRONE          8.800090
# KRONA                    9.460414
# SRI LANKAN RUPEE       178.513655
# FRANC                    0.993726
# BAHT                    31.041928

# %%
for i in new_exchange.columns[:-1]:
    max_value=new_exchange[new_exchange[i]==new_exchange[i].max()]["Year"]
    min_value=new_exchange[new_exchange[i]==new_exchange[i].min()]["Year"]
    print(f"Max value for {i} was {new_exchange[i].max()} in: {max_value[max_value.index[0]]}")
    print(f"Min value for {i} was {new_exchange[i].min()} in: {min_value[min_value.index[0]]}")
#The maximum and minimum values for each rate in history versus the dollar
# Out:
# Max value for AUSTRALIAN DOLLAR was 2.0713 in: 2001
# Min value for AUSTRALIAN DOLLAR was 0.9069 in: 2011
# Max value for EURO was 1.2092 in: 2000
# Min value for EURO was 0.6246 in: 2008
# Max value for NEW ZELAND DOLLAR was 2.551 in: 2000
# Min value for NEW ZELAND DOLLAR was 1.1346 in: 2014
# Max value for UNITED KINGDOM POUND was 0.8287 in: 2019
# Min value for UNITED KINGDOM POUND was 0.4738 in: 2007
# Max value for REAL was 4.2594 in: 2019
# Min value for REAL was 1.5375 in: 2011
# Max value for CANADIAN DOLLAR was 1.6128 in: 2002
# Min value for CANADIAN DOLLAR was 0.9168 in: 2007
# Max value for YUAN was 8.28 in: 2002
# Min value for YUAN was 6.0402 in: 2014
# Max value for HONG KONG DOLLAR was 7.8499 in: 2018
# Min value for HONG KONG DOLLAR was 7.7085 in: 2003
# Max value for WON was 1570.1 in: 2009
# Min value for WON was 903.2 in: 2007
# Max value for MEXICAN PESO was 21.891 in: 2017
# Min value for MEXICAN PESO was 8.946 in: 2001
# Max value for RAND was 16.8845 in: 2016
# Min value for RAND was 5.615 in: 2004
# Max value for SINGAPORE DOLLAR was 1.854 in: 2001
# Min value for SINGAPORE DOLLAR was 1.2007 in: 2011
# Max value for DANISH KRONE was 9.005 in: 2000
# Min value for DANISH KRONE was 4.6605 in: 2008
# Max value for YEN was 134.77 in: 2002
# Min value for YEN was 75.72 in: 2011
# Max value for RINGGIT was 4.496 in: 2017
# Min value for RINGGIT was 2.937 in: 2011
# Max value for NORWEGIAN KRONE was 9.589 in: 2000
# Min value for NORWEGIAN KRONE was 4.9467 in: 2008
# Max value for KRONA was 11.027 in: 2001
# Min value for KRONA was 5.8346 in: 2008
# Max value for SRI LANKAN RUPEE was 182.8 in: 2019
# Min value for SRI LANKAN RUPEE was 72.3 in: 2000
# Max value for FRANC was 1.825 in: 2000
# Min value for FRANC was 0.7296 in: 2011
# Max value for BAHT was 45.82 in: 2001
# Min value for BAHT was 28.6 in: 2013

# %% [markdown]
# # 5) Plotting a graph by year for all columns

# %% [markdown]
# Moving all column names to one column and their values to another

# %%
df_melted=new_exchange.melt(id_vars=["Year"], 
        var_name="Currency name", 
        value_name="Value")
df_melted
# Out:
#         Year      Currency name    Value
# 0       2000  AUSTRALIAN DOLLAR   1.5172
# 1       2000  AUSTRALIAN DOLLAR   1.5239
# 2       2000  AUSTRALIAN DOLLAR   1.5267
# 3       2000  AUSTRALIAN DOLLAR   1.5291
# 4       2000  AUSTRALIAN DOLLAR   1.5272
# ...      ...                ...      ...
# 100375  2019               BAHT  30.1500
# 100376  2019               BAHT  30.1500
# 100377  2019               BAHT  30.1400
# 100378  2019               BAHT  29.9400
# 100379  2019               BAHT  29.7500
#
# [100380 rows x 3 columns]

# %%
sns.set_style("white")
plt.figure(figsize=(20,10))
sns.lineplot(x="Year", y="Value", hue="Currency name", palette='tab10', data=df_melted);
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left');

# %% [markdown]
# Sorting currencies in descending order of their values

# %%
df = new_exchange.iloc[-1,:-1]
df.sort_values(ascending=False)
# Out:
# WON                     1155.4600
# SRI LANKAN RUPEE         181.3000
# YEN                      108.6700
# BAHT                      29.7500
# MEXICAN PESO              18.8600
# RAND                      13.9730
# KRONA                      9.3425
# NORWEGIAN KRONE            8.7823
# HONG KONG DOLLAR           7.7894
# YUAN                       6.9618
# DANISH KRONE               6.6554
# RINGGIT                    4.0918
# REAL                       4.0190
# NEW ZELAND DOLLAR          1.4826
# AUSTRALIAN DOLLAR          1.4225
# SINGAPORE DOLLAR           1.3446
# CANADIAN DOLLAR            1.2962
# FRANC                      0.9677
# EURO                       0.8907
# UNITED KINGDOM POUND       0.7536
# Name: 5216, dtype: float64
